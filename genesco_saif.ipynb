# %%
import pandas as pd
import numpy as np
import pandas as pd
from datetime import datetime

pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 500)

import matplotlib.pyplot as plt

# %%
gen_ex = pd.read_csv('0826export.csv')

# %%
cd data
# Out:
# C:\Users\shaju\Git\Projects\percent-comp-increase-huarache\data

# %%
gen_ex.head()
# Out:
#    DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 0    7   1504      6-Feb-16         2017            1             1
# 1    7   1504     13-Feb-16         2017            2             1
# 2    7   1504     20-Feb-16         2017            3             1
# 3    7   1504     27-Feb-16         2017            4             1
# 4    7   1504      5-Mar-16         2017            5             2
#
#    SALES_AMT_TY  SALES_AMT_LY COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# 0      22003.18      21266.87    3.46%            2016               1
# 1      17499.35      23490.64  -25.51%            2016               2
# 2      15004.60      22318.80  -32.77%            2016               3
# 3      12770.09      17296.40  -26.17%            2016               4
# 4      19920.51      24553.82  -18.87%            2016               5
#
#    FISCAL_MONTH_LY WEEK_END_DATE_LY  MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  \
# ...

# %%
gen_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27193 entries, 0 to 27192
# Columns: 104 entries, DIV to TOT_AVG_TENURE_DAYS
# dtypes: float64(51), int64(51), object(2)
# memory usage: 21.6+ MB

# %%
corr_gen = gen_ex.corr()

# %%
gen_ex.to_csv('gen_ex.csv')

# %%
corr_gen
# Out:
#                                DIV     STORE  FISCAL_YEAR  FISCAL_WEEK  \
# DIV                            NaN       NaN          NaN          NaN
# STORE                          NaN  1.000000     0.012711    -0.001392
# FISCAL_YEAR                    NaN  0.012711     1.000000    -0.230394
# FISCAL_WEEK                    NaN -0.001392    -0.230394     1.000000
# FISCAL_MONTH                   NaN -0.001419    -0.230556     0.996390
# SALES_AMT_TY                   NaN -0.190561     0.004984     0.112719
# SALES_AMT_LY                   NaN -0.188302    -0.011146     0.116275
# FISCAL_YEAR_LY                 NaN  0.012765     0.997312    -0.219736
# FISCAL_WEEK_LY                 NaN -0.001619    -0.211032     0.964275
# FISCAL_MONTH_LY                NaN -0.001593    -0.215626     0.962439
# MARK_DOWN_AMT_TY               NaN  0.324965     0.031811     0.127231
# MARK_DOWN_AMT_LY               NaN  0.288930     0.011505     0.199433
# ...

# %%
corr_gen.to_csv('corr_gen.csv')

# %%
genex_corr = gen_ex.corr()

# %%
genex_corr.head()
# Out:
#               DIV     STORE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# DIV           NaN       NaN          NaN          NaN           NaN
# STORE         NaN  1.000000     0.012711    -0.001392     -0.001419
# FISCAL_YEAR   NaN  0.012711     1.000000    -0.230394     -0.230556
# FISCAL_WEEK   NaN -0.001392    -0.230394     1.000000      0.996390
# FISCAL_MONTH  NaN -0.001419    -0.230556     0.996390      1.000000
#
#               SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  \
# DIV                    NaN           NaN       NaN             NaN
# STORE            -0.190561     -0.188302  0.005457        0.012765
# FISCAL_YEAR       0.004984     -0.011146 -0.005138        0.997312
# FISCAL_WEEK       0.112719      0.116275 -0.001508       -0.219736
# FISCAL_MONTH      0.111989      0.115534 -0.001705       -0.220948
#
#               FISCAL_WEEK_LY  FISCAL_MONTH_LY  MARK_DOWN_AMT_TY  \
# DIV                      NaN              NaN               NaN
# ...

# %%
print(genex_corr.columns.values)
# Out:
# ['DIV' 'STORE' 'FISCAL_YEAR' 'FISCAL_WEEK' 'FISCAL_MONTH' 'SALES_AMT_TY'
#  'SALES_AMT_LY' 'COMP_PCT' 'FISCAL_YEAR_LY' 'FISCAL_WEEK_LY'
#  'FISCAL_MONTH_LY' 'MARK_DOWN_AMT_TY' 'MARK_DOWN_AMT_LY'
#  'PAYROLL_ADJ_HOURS' 'NUM_OF_DAYS' 'STRAK_TRAFFIC' 'STRAK_HRS'
#  'STRAK_SALES_AMT' 'STRAK_TRANSACTION_NUM' 'CP_VALID_EMAILS'
#  'CP_VALID_MAILING_ADDRESS' 'CP_TOTAL_TRANS' 'CP_EMAILS_PER_TRANS'
#  'CP_MAIL_ADD_CAPTURE_RATE' 'CP_EMAIL_MAIL_CAPTURE_RATE'
#  'CP_TOTAL_EMAIL_TRANS' 'SPECIAL_ORDER_AMT' 'SALES_UNITS' 'SALES_VALUE'
#  'SHOES_UNITS' 'SHOES_VALUE' 'MULTI_UNITS' 'MULTI_VALUE' 'PAYROLL_UNITS'
#  'PAYROLL_VALUE' 'ACCESSORY_UNITS' 'ACCESSORY_VALUE'
#  'ACCESSORY_HOSIERY_UNITS' 'ACCESSORY_HOSIERY_VALUE'
#  'ACCESSORY_SHOE_TREES_UNITS' 'ACCESSORY_SHOE_TREES_VALUE'
#  'ACCESSORY_COATS_UNITS' 'ACCESSORY_COATS_VALUE'
#  'ACCESSORY_SHIRT_SWEATER_UNITS' 'ACCESSORY_SHIRT_SWEATER_VALUE'
#  'ACCESSORY_PLGS_LUGGAGE_UNITS' 'ACCESSORY_PLGS_LUGGAGE_VALUE'
# ...

# %%
gen_ex.loc[:, gen_ex.dtypes == object]
# Out:
#       WEEK_END_DATE WEEK_END_DATE_LY
# 0         13-Jan-18        14-Jan-17
# 1          8-Oct-16        10-Oct-15
# 2         22-Sep-18        23-Sep-17
# 3         15-Oct-16        17-Oct-15
# 4         12-Jan-19        13-Jan-18
# 5         25-Mar-17        26-Mar-16
# 6         10-Feb-18        11-Feb-17
# 7          9-Mar-19        10-Mar-18
# 8          2-Jul-16         4-Jul-15
# 9         20-Aug-16        22-Aug-15
# 10         2-Feb-19         3-Feb-18
# 11        26-Jan-19        27-Jan-18
# 12        10-Feb-18        11-Feb-17
# 13        12-Jan-19        13-Jan-18
# 14        14-Jan-17        16-Jan-16
# 15         3-Jun-17         4-Jun-16
# 16        25-Mar-17        26-Mar-16
# 17         9-Jul-16        11-Jul-15
# 18        18-Mar-17        19-Mar-16
# 19         7-Apr-18         8-Apr-17
# 20        25-Nov-17        26-Nov-16
# 21         1-Sep-18         2-Sep-17
# 22        16-Sep-17        17-Sep-16
# 23        15-Dec-18        16-Dec-17
# ...

# %%
gen_ex.columns
# Out:
# Index(['DIV', 'STORE', 'WEEK_END_DATE', 'FISCAL_YEAR', 'FISCAL_WEEK',
#        'FISCAL_MONTH', 'SALES_AMT_TY', 'SALES_AMT_LY', 'COMP_PCT',
#        'FISCAL_YEAR_LY',
#        ...
#        'AVG_AM_TENURE_DAYS', 'FT_COUNT', 'FT_TENURE_DAYS',
#        'AVG_FT_TENURE_DAYS', 'PT_COUNT', 'PT_TENURE_DAYS',
#        'AVG_PT_TENURE_DAYS', 'NUM_OF_EMPS', 'TOT_TENURE_DAYS',
#        'TOT_AVG_TENURE_DAYS'],
#       dtype='object', length=104)

# %%
gen_ex.columns
# Out:
# Index(['DIV', 'STORE', 'WEEK_END_DATE', 'FISCAL_YEAR', 'FISCAL_WEEK',
#        'FISCAL_MONTH', 'SALES_AMT_TY', 'SALES_AMT_LY', 'COMP_PCT',
#        'FISCAL_YEAR_LY',
#        ...
#        'AVG_AM_TENURE_DAYS', 'FT_COUNT', 'FT_TENURE_DAYS',
#        'AVG_FT_TENURE_DAYS', 'PT_COUNT', 'PT_TENURE_DAYS',
#        'AVG_PT_TENURE_DAYS', 'NUM_OF_EMPS', 'TOT_TENURE_DAYS',
#        'TOT_AVG_TENURE_DAYS'],
#       dtype='object', length=104)

# %%
gen_ex.plot(kind='scatter',x='SALES_AMT_TY',y='WEEK_END_DATE',color='red')
plt.show()

# %%
gen_ex.to_csv('gen_ex.csv')

# %%
gen_ex['WEEK_END_DATE'] = pd.to_datetime(gen_ex['WEEK_END_DATE'])

# %%
gen_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27193 entries, 0 to 27192
# Columns: 104 entries, DIV to TOT_AVG_TENURE_DAYS
# dtypes: datetime64[ns](1), float64(51), int64(51), object(1)
# memory usage: 21.6+ MB

# %%
import statsmodels.api as sm

X = gen_ex["MARK_DOWN_AMT_TY"]
y = gen_ex["SALES_AMT_TY"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           SALES_AMT_TY   R-squared (uncentered):                   0.706
# Model:                            OLS   Adj. R-squared (uncentered):              0.706
# Method:                 Least Squares   F-statistic:                          6.524e+04
# Date:                Sat, 05 Oct 2019   Prob (F-statistic):                        0.00
# Time:                        12:19:12   Log-Likelihood:                     -2.9490e+05
# No. Observations:               27193   AIC:                                  5.898e+05
# Df Residuals:                   27192   BIC:                                  5.898e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
weekend = gen_ex[['SALES_AMT_TY']]
weekend.rolling(12).mean().plot(figsize=(20,10), linewidth=1, fontsize=20)
plt.xlabel('Sales', fontsize=20);

# %%
#genesco_sales = gen_ex['WEEK_END_DATE','SALES_AMT_TY']

genesco_sales = genesco_sales.loc[:, ['WEEK_END_DATE','SALES_AMT_TY']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-e71875c45d39> in <module>
#       1 #genesco_sales = gen_ex['WEEK_END_DATE','SALES_AMT_TY']
#       2
# ----> 3 genesco_sales = genesco_sales.loc[:, ['WEEK_END_DATE','SALES_AMT_TY']]
#
# NameError: name 'genesco_sales' is not defined

# %%
genesco_sales
# Out:
# 0        22003.18
# 1        17499.35
# 2        15004.60
# 3        12770.09
# 4        19920.51
# 5        16906.51
# 6        18074.96
# 7        15263.72
# 8        19582.20
# 9        20684.58
# 10       15122.71
# 11       19203.37
# 12       20899.00
# 13       26574.28
# 14       12520.88
# 15       16006.67
# 16       17246.05
# 17       17261.42
# 18       19706.61
# 19       17608.54
# 20       12599.97
# 21       15144.95
# 22       11133.11
# 23       12567.96
# 24       14977.31
# 25       14795.54
# 26       13948.54
# 27       13736.29
# 28       15892.23
# 29       14913.68
#            ...
# 27163    26980.06
# 27164    13369.45
# 27165    14302.18
# 27166    14427.25
# 27167    16337.85
# 27168    16753.80
# 27169    16786.35
# 27170    18076.80
# 27171    17354.12
# 27172    16071.44
# 27173    23845.72
# 27174    19552.47
# 27175    15803.12
# 27176    16489.52
# 27177    17962.28
# 27178    16147.80
# 27179    16338.13
# 27180    16747.76
# 27181    13076.55
# ...

# %%
gen_sales = gen_ex[['SALES_AMT_TY']]
weekend.rolling(12).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)
plt.xlabel('Sales', fontsize=20);

# %%
corr_mat = pd.read_csv('Data/corr_mat.csv')

# %%
corr_mat
# Out:
#                         Unnamed: 0      DIV         STORE WEEK_END_DATE  \
# 0                      PAYROLL_PCT  #DIV/0!    0.06420547   0.003328216
# 1                 FOOTWEAR_AMT_PCT  #DIV/0!   0.264760657  -0.059767753
# 2               FOOTWEAR_UNITS_PCT  #DIV/0!   0.391016897   0.059105025
# 3                   AVG_UNIT_PRICE  #DIV/0!   0.720584085   -0.04590708
# 4         CP_MAIL_ADD_CAPTURE_RATE  #DIV/0!  -0.136634821   0.091608361
# 5       CP_EMAIL_MAIL_CAPTURE_RATE  #DIV/0!  -0.107897857   0.253828649
# 6             STRAK_CONVERSION_PCT  #DIV/0!   0.153743409   0.111087585
# 7         SPECIAL_ORDER_PCT_TO_SLS  #DIV/0!   -0.29133846  -0.036438431
# 8                  UNITS_PER_TRANS  #DIV/0!   0.266596463  -0.095274765
# 9                   SHOE_MULTI_PCT  #DIV/0!   0.538551209   0.028356025
# 10                TY_MARK_DOWN_PCT  #DIV/0!   0.634795644   0.080742576
# 11                   MULTI_AMT_PCT  #DIV/0!    0.46502778   0.020757368
# ...

# %%
Sales= pd.read_csv('Data\Sales.csv')

# %%
Sales
# Out:
#     2016    135129446
# 0   Qtr1  20009658.94
# 1   Qtr2  36404531.22
# 2   Qtr3  31093925.35
# 3   Qtr4  47621330.50
# 4   Qtr1  24368353.68
# 5   Qtr2  35418765.87
# 6   Qtr3  33761734.36
# 7   Qtr4  49370980.44
# 8   Qtr1  36410263.42
# 9   Qtr2  40682476.81
# 10  Qtr3  35993950.12
# 11  Qtr4  52064235.04
# 12  Qtr1  38246739.82
# 13  Qtr2  40364810.90
# 14  Qtr3  12701633.91

# %%
Sales.plot(kind='bar',x='2016',y='135129446',color='g',alpha=0.5,figsize=(20,10))
plt.xlabel('Year')
plt.ylabel('Sales')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d0c170477e4e> in <module>
# ----> 1 Sales.plot(kind='bar',x='2016',y='135129446',color='g',alpha=0.5,figsize=(20,10))
#       2 plt.xlabel('Year')
#       3 plt.ylabel('Sales')
#       4
#       5 plt.show()
#
# NameError: name 'Sales' is not defined

# %%
Mark_down= pd.read_csv('Data\Mark_down.csv')

# %%
Mark_down['Sum of SALES_AMT_TY'].describe()
# Out:
# count    1.900000e+01
# mean     5.626457e+07
# std      4.395520e+07
# min      1.270163e+07
# 25%      3.459025e+07
# 50%      3.824674e+07
# 75%      5.071761e+07
# max      1.651509e+08
# Name: Sum of SALES_AMT_TY, dtype: float64

# %%
import seaborn as sns

f, x = plt.subplots(figsize=(16, 8))
corr = Mark_down.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
salespay= pd.read_csv('salespay.csv')

# %%
salespay.describe()
# Out:
#        Sum of SALES_AMT_PER_PAY_HOUR  Sum of AVG_PAY_PER_HR
# count                   1.900000e+01              19.000000
# mean                    3.846507e+05           51445.371579
# std                     2.976443e+05           39437.616253
# min                     9.122370e+04           13956.900000
# 25%                     2.456520e+05           33183.795000
# 50%                     2.695271e+05           37292.390000
# 75%                     3.193189e+05           38569.650000
# max                     1.123800e+06          147613.120000

# %%
Sales_perhour = salespay['Sum of SALES_AMT_PER_PAY_HOUR']
PAY_PER_HR = salespay['Sum of AVG_PAY_PER_HR']
plt.scatter(Sales_perhour, PAY_PER_HR, edgecolors='r')
plt.xlabel('Sales_perhour')
plt.ylabel('PAY_PER_HR)')
plt.title('Sales Vs Pay')
plt.show()

# %%
num_bins = 'auto'
plt.hist(salespay['Sum of SALES_AMT_PER_PAY_HOUR'], num_bins, normed=1, facecolor='purple', alpha=0.5)
plt.grid(axis='x', alpha=0.75)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Sales_per_hour')
plt.ylabel('Frequency')

plt.show()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
import statsmodels.api as sm

X = salespay["Sum of SALES_AMT_PER_PAY_HOUR"]
y = salespay["Sum of AVG_PAY_PER_HR"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1416: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ...
# Dep. Variable:     Sum of AVG_PAY_PER_HR   R-squared (uncentered):                   0.999
# Model:                               OLS   Adj. R-squared (uncentered):              0.999
# Method:                    Least Squares   F-statistic:                          1.612e+04
# Date:                   Tue, 01 Oct 2019   Prob (F-statistic):                    4.96e-28
# Time:                           00:12:11   Log-Likelihood:                         -172.70
# No. Observations:                     19   AIC:                                      347.4
# Df Residuals:                         18   BIC:                                      348.3
# ...

# %%
sales2017 = pd.read_csv('Data\sales2017.csv')

# %%
sales2017.head()
# Out:
#    Week no       Sales
# 0        1  2240971.03
# 1        2  2426034.01
# 2        3  2442262.20
# 3        4  2290063.57
# 4        5  2533381.88

# %%
sales2017.plot(kind='bar',x='Week no',y='Sales',color='g',alpha=0.7,figsize=(20,10))
plt.xlabel('Week no')
plt.ylabel('Sales')

plt.show()

plt.savefig('sales2017.png')

# %%
plt.savefig('sales2017.png')

# %%
sales2019 = pd.read_csv('sales2019.csv')

# %%
sales2019.plot(kind='bar',x='Week no',y='Sales',color='purple',alpha=0.7,figsize=(20,10))
plt.xlabel('Week no')
plt.ylabel('Sales')

plt.show()
plt.savefig('sales2019.png')

# %%
plt.savefig('sales2019.png')

# %%
mark_vs_sales_2019 = pd.read_csv('Data/mark_sales_2019.csv')

# %%
mark_vs_sales_2019.head()
# Out:
#   WEEK_END_DATE  FISCAL_YEAR  SALES_AMT_TY  SALES_AMT_LY  Diff_Sales  \
# 0     10-Feb-18         2019       8197.88      26170.64   -17972.76
# 1     10-Feb-18         2019       1631.14       4862.58    -3231.44
# 2     10-Feb-18         2019       5740.32      12794.19    -7053.87
# 3     10-Feb-18         2019       3179.56       6892.77    -3713.21
# 4     10-Feb-18         2019       4434.42       8705.29    -4270.87
#
#    MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  Diff_mark_down
# 0            574.95           1273.57         -698.62
# 1            666.70           1325.64         -658.94
# 2            844.62           1797.01         -952.39
# 3            400.84            919.55         -518.71
# 4            637.59            949.71         -312.12

# %%
mark_vs_sales_2020 = pd.read_csv('Data/mark_sales_2020.csv')
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mark_vs_sales_2020.head()
# Out:
#       WEEK_END_DATE  FISCAL_YEAR  SALES_AMT_TY  SALES_AMT_LY  Diff_Sales  \
# 0  February 9, 2019       2020.0       4073.39       8994.51    -4921.12
# 1  February 9, 2019       2020.0       3921.48       7223.87    -3302.39
# 2  February 9, 2019       2020.0       9260.74      16295.89    -7035.15
# 3  February 9, 2019       2020.0       5665.05       9700.83    -4035.78
# 4  February 9, 2019       2020.0       8488.73      14153.42    -5664.69
#
#    MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  Diff_mark_down
# 0            278.34            684.70         -406.36
# 1             47.40            172.86         -125.46
# 2           1229.04           1897.78         -668.74
# 3            291.33            253.65           37.68
# 4           1162.78           1830.56         -667.78

# %%
mark_vs_sales_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4076 entries, 0 to 4075
# Data columns (total 8 columns):
# WEEK_END_DATE       4076 non-null object
# FISCAL_YEAR         4076 non-null int64
# SALES_AMT_TY        4076 non-null float64
# SALES_AMT_LY        4076 non-null float64
# Diff_Sales          4076 non-null float64
# MARK_DOWN_AMT_TY    4076 non-null float64
# MARK_DOWN_AMT_LY    4076 non-null float64
# Diff_mark_down      4076 non-null float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 254.8+ KB

# %%
import statsmodels.api as sm

X = mark_vs_sales_2019["Diff_mark_down"]
y = mark_vs_sales_2019["Diff_Sales"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             Diff_Sales   R-squared (uncentered):                   0.297
# Model:                            OLS   Adj. R-squared (uncentered):              0.297
# Method:                 Least Squares   F-statistic:                              1724.
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):                   1.60e-314
# Time:                        20:02:32   Log-Likelihood:                         -39459.
# No. Observations:                4076   AIC:                                  7.892e+04
# Df Residuals:                    4075   BIC:                                  7.893e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x="Diff_Sales", y="Diff_mark_down", data=mark_vs_sales_2019 );

# %%
mark_vs_sales_2019.corr()
# Out:
#                   FISCAL_YEAR  SALES_AMT_TY  SALES_AMT_LY  Diff_Sales  \
# FISCAL_YEAR               NaN           NaN           NaN         NaN
# SALES_AMT_TY              NaN      1.000000      0.907345    0.412007
# SALES_AMT_LY              NaN      0.907345      1.000000   -0.009215
# Diff_Sales                NaN      0.412007     -0.009215    1.000000
# MARK_DOWN_AMT_TY          NaN      0.663137      0.585795    0.307679
# MARK_DOWN_AMT_LY          NaN      0.609466      0.686521   -0.038309
# Diff_mark_down            NaN      0.094758     -0.153737    0.558619
#
#                   MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  Diff_mark_down
# FISCAL_YEAR                    NaN               NaN             NaN
# SALES_AMT_TY              0.663137          0.609466        0.094758
# SALES_AMT_LY              0.585795          0.686521       -0.153737
# Diff_Sales                0.307679         -0.038309        0.558619
# ...

# %%
mark_vs_sales_2019['SALES_AMT_TY'].sum()
# Out:
# 77129788.49

# %%
mark_vs_sales_2019['Diff_mark_down'].sum()
# Out:
# 52997.43999999997

# %%
mark_vs_sales_2020.corr()
# Out:
#                   FISCAL_YEAR  SALES_AMT_TY  SALES_AMT_LY  Diff_Sales  \
# FISCAL_YEAR               NaN           NaN           NaN         NaN
# SALES_AMT_TY              NaN      1.000000      0.916926    0.280748
# SALES_AMT_LY              NaN      0.916926      1.000000   -0.125582
# Diff_Sales                NaN      0.280748     -0.125582    1.000000
# MARK_DOWN_AMT_TY          NaN      0.477352      0.404196    0.214588
# MARK_DOWN_AMT_LY          NaN      0.590102      0.661637   -0.124285
# Diff_mark_down            NaN      0.145547     -0.025110    0.422231
#
#                   MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  Diff_mark_down
# FISCAL_YEAR                    NaN               NaN             NaN
# SALES_AMT_TY              0.477352          0.590102        0.145547
# SALES_AMT_LY              0.404196          0.661637       -0.025110
# Diff_Sales                0.214588         -0.124285        0.422231
# ...

# %%
mark_vs_sales_2020['SALES_AMT_TY'].sum()
# Out:
# 77236450.24

# %%
mark_vs_sales_2020['Diff_mark_down'].sum()
# Out:
# 2150752.6599999997

# %%
mark_vs_sales_2019.plot(kind='bar',x='Diff_Sales',y='Diff_mark_down',color='g',alpha=0.7,figsize=(20,10))
plt.xlabel('Diff_Sales')
plt.ylabel('Diff_mark_down')

plt.show()

plt.savefig('mark_vs_sales_2019.png')

# %%
f, x = plt.subplots(figsize=(16, 8))
corr = mark_vs_sales_2019.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
sns.set_style('darkgrid')
sns.distplot((gen_ex['SALES_AMT_TY']))

# %%
sns.set_style('darkgrid')
sns.distplot((gen_ex['MARK_DOWN_AMT_TY']))

# %%
gen_ex.columns
# Out:
# Index(['DIV', 'STORE', 'WEEK_END_DATE', 'FISCAL_YEAR', 'FISCAL_WEEK',
#        'FISCAL_MONTH', 'SALES_AMT_TY', 'SALES_AMT_LY', 'COMP_PCT',
#        'FISCAL_YEAR_LY',
#        ...
#        'AVG_AM_TENURE_DAYS', 'FT_COUNT', 'FT_TENURE_DAYS',
#        'AVG_FT_TENURE_DAYS', 'PT_COUNT', 'PT_TENURE_DAYS',
#        'AVG_PT_TENURE_DAYS', 'NUM_OF_EMPS', 'TOT_TENURE_DAYS',
#        'TOT_AVG_TENURE_DAYS'],
#       dtype='object', length=104)

# %%
shoe_acc= pd.read_csv('Data/shoe_acc.csv')

# %%
shoe_acc.head()
# Out:
#    Month  Total_sales  Shoe_sales  Accessories
# 0      1   9399330.81  5910170.78   3489160.03
# 1      2  10610328.13  6809772.39   3800555.74
# 2      3  13944952.78  8804521.74   5140431.04
# 3      4  11623539.56  7428065.32   4195474.24
# 4      5  10836038.88  7046570.69   3789468.19

# %%
shoe_acc.corr()
# Out:
#                 Month  Total_sales  Shoe_sales  Accessories
# Month        1.000000     0.507961    0.497216     0.501808
# Total_sales  0.507961     1.000000    0.985576     0.979968
# Shoe_sales   0.497216     0.985576    1.000000     0.932130
# Accessories  0.501808     0.979968    0.932130     1.000000

# %%
f, x = plt.subplots(figsize=(16, 8))
corr = shoe_acc.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
import statsmodels.api as sm

X = shoe_acc["Shoe_sales"]
y = shoe_acc["Total_sales"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            Total_sales   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          2.101e+04
# Date:                Sat, 05 Oct 2019   Prob (F-statistic):                    3.36e-57
# Time:                        12:27:10   Log-Likelihood:                         -616.71
# No. Observations:                  42   AIC:                                      1235.
# Df Residuals:                      41   BIC:                                      1237.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm

X = shoe_acc["Accessories"]
y = shoe_acc["Total_sales"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            Total_sales   R-squared (uncentered):                   0.995
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              8055.
# Date:                Sat, 05 Oct 2019   Prob (F-statistic):                    1.09e-48
# Time:                        12:55:59   Log-Likelihood:                         -636.78
# No. Observations:                  42   AIC:                                      1276.
# Df Residuals:                      41   BIC:                                      1277.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
shoe_acc.groupby('Month')['Total_sales'].nunique().plot(kind='bar')
plt.show()

# %%
sns.countplot(shoe_acc['Month'])

# %%
ax = shoe_acc[["Total_sales","Shoe_sales","Accessories"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
shoe_acc.columns
# Out:
# Index(['Month', 'Total_sales', 'Shoe_sales', 'Accessories'], dtype='object')

# %%
shoe_acc.apply(np.mean)
# Out:
# Month          6.071429e+00
# Total_sales    1.272651e+07
# Shoe_sales     7.911479e+06
# Accessories    4.815031e+06
# dtype: float64

# %%
shoe_acc.describe()
# Out:
#            Month   Total_sales    Shoe_sales   Accessories
# count  42.000000  4.200000e+01  4.200000e+01  4.200000e+01
# mean    6.071429  1.272651e+07  7.911479e+06  4.815031e+06
# std     3.466867  2.976569e+06  1.637004e+06  1.391042e+06
# min     1.000000  5.027540e+06  3.179815e+06  1.847724e+06
# 25%     3.000000  1.117201e+07  7.052901e+06  3.881013e+06
# 50%     6.000000  1.237694e+07  7.782736e+06  4.516038e+06
# 75%     9.000000  1.404379e+07  8.674121e+06  5.320668e+06
# max    12.000000  2.233992e+07  1.338471e+07  9.016355e+06

# %%
from scipy import stats

corr = stats.pearsonr(shoe_acc.Total_sales,shoe_acc.Shoe_sales)
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 1.7518024416544545e-32
# cor:		 0.9855762690538606

# %%
F, p = stats.f_oneway(shoe_acc['Total_sales'], shoe_acc['Shoe_sales'], shoe_acc['Accessories'])

# %%
F, p
# Out:
# (148.62206354100027, 1.5269074049687208e-33)

# %%
import pingouin as pg

data = ('Data/shoe_acc.csv')

df = pd.read_csv('Data/shoe_acc.csv', index_col=0)

aov = pg.anova(data=df, dv='Total_sales', between='Shoe_sales', detailed=True)
print(aov)
# Out:
#        Source            SS  DF           MS  F p-unc np2
# 0  Shoe_sales  3.632585e+14  41  8.85996e+12  -     -   1
# 1      Within  0.000000e+00   0            -  -     -   -
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\pingouin\parametric.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   mserror = sserror / ddof2
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   *Must* be overridden by distributions which have support dependent
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   *Must* be overridden by distributions which have support dependent
# ...

# %%
gen_corr_2018 = pd.read_csv('gen_2018_corr.csv')

# %%
gen_corr_2018
# Out:
#                         Unnamed: 0  Unnamed: 0.1  DIV     STORE  FISCAL_YEAR  \
# 0                       Sales_diff      0.030586  NaN  0.026120          NaN
# 1                         COMP_PCT      0.027054  NaN  0.022304          NaN
# 2         STRAK_COMP_TRAFFIC_DELTA      0.001951  NaN -0.004746          NaN
# 3           SALES_AMT_PER_PAY_HOUR     -0.150196  NaN -0.156330          NaN
# 4                      SALES_UNITS      0.083358  NaN  0.074612          NaN
# 5                     SALES_AMT_TY     -0.150640  NaN -0.171352          NaN
# 6                      SALES_VALUE     -0.150640  NaN -0.171352          NaN
# 7                  STRAK_SALES_AMT     -0.150737  NaN -0.171436          NaN
# 8                  ACCESSORY_UNITS      0.017386  NaN -0.001895          NaN
# 9                      SHOES_UNITS      0.230578  NaN  0.249338          NaN
# 10                  AVG_PAY_PER_HR     -0.174645  NaN -0.185198          NaN
# ...

# %%
gen_corr_corr = gen_corr_2018.corr()

# %%
gen_corr_corr.to_csv('gen_corr_corr.csv')

# %%
sales_delta = pd.read_csv('sales_delta.csv')

# %%
sales_delta.head()
# Out:
#    SALES_AMT_TY  STRAK_COMP_TRAFFIC_DELTA
# 0      22003.18                 -0.062981
# 1      17499.35                 -0.360549
# 2      15004.60                 -0.412661
# 3      12770.09                 -0.350361
# 4      19920.51                 -0.301348

# %%
ax = sales_delta[["SALES_AMT_TY","STRAK_COMP_TRAFFIC_DELTA"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
sales_delta2 = pd.read_csv('sales_delta2.csv')

# %%
sales_delta2
# Out:
#    Year  Sum of STRAK_TRAFFIC  Sum of STRAK_TRANSACTION_NUM  \
# 0  2016               8003834                        937670
# 1  2017               8414607                        996713
# 2  2018               8957674                       1126916
# 3  2019               4901338                        644498
#
#    Sum of SALES_AMT_TY
# 0         1.351294e+08
# 1         1.429198e+08
# 2         1.651509e+08
# 3         9.131318e+07

# %%
import statsmodels.api as sm

X = sales_delta2["Sum of STRAK_TRAFFIC"]
y = sales_delta2["Sum of SALES_AMT_TY"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# C:\Users\shaju\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\stats\stattools.py:71: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     Sum of SALES_AMT_TY   R-squared (uncentered):                   0.998
# Model:                             OLS   Adj. R-squared (uncentered):              0.997
# Method:                  Least Squares   F-statistic:                              1573.
# Date:                 Tue, 22 Oct 2019   Prob (F-statistic):                    3.53e-05
# Time:                         19:10:58   Log-Likelihood:                         -68.068
# No. Observations:                    4   AIC:                                      138.1
# Df Residuals:                        3   BIC:                                      137.5
# ...

# %%
import seaborn as sns

f, x = plt.subplots(figsize=(16, 8))
corr = sales_delta2.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
all_conversion = pd.read_csv('all_conver.csv')

# %%
all_conversion
# Out:
#         Year  Sum of STRAK_TRAFFIC  Sum of STRAK_TRANSACTION_NUM  \
# 0   2016Qtr1               1118355                        135904
# 1   2016Qtr2               2080003                        251255
# 2   2016Qtr3               2058391                        224240
# 3   2016Qtr4               2747085                        326271
# 4   2017Qtr1               1466916                        176235
# 5   2017Qtr2               2019207                        247095
# 6   2017Qtr3               2133354                        239016
# 7   2017Qtr4               2795130                        334367
# 8   2018Qtr1               2016128                        254627
# 9   2018Qtr2               2150773                        279842
# 10  2018Qtr3               2067082                        245318
# 11  2018Qtr4               2723691                        347129
# 12  2019Qtr1               2064951                        270993
# ...

# %%
all_conversion.corr()
# Out:
#                               Sum of STRAK_TRAFFIC  \
# Sum of STRAK_TRAFFIC                      1.000000
# Sum of STRAK_TRANSACTION_NUM              0.977645
# Strak_conversion                         -0.037940
# Sum of SALES_AMT_TY                       0.972112
#
#                               Sum of STRAK_TRANSACTION_NUM  Strak_conversion  \
# Sum of STRAK_TRAFFIC                              0.977645         -0.037940
# Sum of STRAK_TRANSACTION_NUM                      1.000000          0.171879
# Strak_conversion                                  0.171879          1.000000
# Sum of SALES_AMT_TY                               0.997856          0.186108
#
#                               Sum of SALES_AMT_TY
# Sum of STRAK_TRAFFIC                     0.972112
# Sum of STRAK_TRANSACTION_NUM             0.997856
# Strak_conversion                         0.186108
# Sum of SALES_AMT_TY                      1.000000

# %%
import seaborn as sns

f, x = plt.subplots(figsize=(16, 8))
corr = all_conversion.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
import statsmodels.api as sm

X = all_conversion["Sum of STRAK_TRANSACTION_NUM"]
y = all_conversion["Sum of SALES_AMT_TY"]

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     Sum of SALES_AMT_TY   R-squared (uncentered):                   0.999
# Model:                             OLS   Adj. R-squared (uncentered):              0.999
# Method:                  Least Squares   F-statistic:                          2.459e+04
# Date:                 Sat, 26 Oct 2019   Prob (F-statistic):                    4.04e-24
# Time:                         10:17:29   Log-Likelihood:                         -226.68
# No. Observations:                   15   AIC:                                      455.4
# Df Residuals:                       14   BIC:                                      456.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Every 1 unit increase in conversion rate , their sales amount will increase by 29100000(29.1 million)

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 
series = read_csv('0826export.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dcf6ff2bf667> in <module>
#       8         return datetime.strptime('190'+x, '%Y-%m')
#       9
# ---> 10 series = read_csv('0826export.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#      11 # fit model
#      12 model = ARIMA(series, order=(5,1,0))
#
# ...
